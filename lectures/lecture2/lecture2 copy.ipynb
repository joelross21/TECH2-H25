# %% [markdown]
# # Introduction to pandas
#
#
# ## Motivation
#
# So far, we have encountered built-in Python containers (`list`, `tuple`, `dict`)
# and NumPy arrays as the only way to store data.
# However, while NumPy arrays are great for storing *homogenous* data
# without any particular structure, they are somewhat limited when
# we want to use them for data analysis.
#
# For example, we usually want to process data sets with
#
# 1.  several variables;
# 2.  multiple observations, which need not be identical across
#     variables (some values may be missing);
# 3.  non-homogenous data types: for examples,
#     names need to be stored as strings, birthdays as dates and income as
#     a floating-point number.
#
# While NumPy can in principle handle such situations, it puts all the
# burden on the user. Most users would prefer to not have to deal
# with such low-level details.
#
# Pandas was created to offer more versatile data structures that are
# straightforward to use for storing, manipulating and analyzing
# heterogeneous data:
#
# 1.  Data is clearly organized in *variables* and *observations*, similar
#     to econometrics programs such as Stata and R using `data.frame`.
#
# 2.  Each variable is permitted to have a *different* data type.
#
# 3.  We can use *labels* to select observations instead of having to use
#     a linear numerical index as with NumPy.
#
#     We could, for example, index a data set using National Insurance Numbers
#     or time stamps for time series data.
#
# 4.  Pandas offers many convenient data aggregation and reduction
#     routines that can be applied to subsets of data.
#
#     For example, we can easily group observations by city and compute average
#     incomes.
#
# 5.  Pandas also offers many convenient data import / export functions that
#     go beyond what's in NumPy.
#
# Should we be using pandas at all times, then? No!
#
# -   For low-level tasks where performance is essential, use NumPy.
# -   For homogenous data without any particular data structure, use NumPy.
# -   On the other hand, if data is heterogeneous, needs to be imported from
#     an external data source and cleaned or transformed before
#     performing computations, use pandas.
#
# There are numerous tutorials on pandas on the internet.
# Useful additional material includes:
#
# -   The official [user guide](https://pandas.pydata.org/docs/user_guide/index.html).
# -   The official [pandas cheat sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
#     which nicely illustrates the most frequently used operations.
# -   The official [API reference](https://pandas.pydata.org/docs/reference/index.html) with details on
#     every pandas object and function.
# -   There are numerous tutorials (including videos) available
#     on the internet. See [here](https://pandas.pydata.org/docs/getting_started/tutorials.html)
#     for a list.

# %%
#for fun, going through w3 schools

import pandas as pd

DATA_PATH = "C:/Users/Bruker/OneDrive - Norwegian School of Economics/TECH2/TECH2-H25/data"

file = f'{DATA_PATH}/titanic.csv'

df = pd.read_csv(file)

print(df.to_string())
# Out:
#      PassengerId  Survived  Pclass                                                                                Name     Sex    Age              Ticket      Fare            Cabin Embarked
# 0              1         0       3                                                             Braund, Mr. Owen Harris    male  22.00           A/5 21171    7.2500              NaN        S
# 1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.00            PC 17599   71.2833              C85        C
# 2              3         1       3                                                               Heikkinen, Miss Laina  female  26.00    STON/O2. 3101282    7.9250              NaN        S
# 3              4         1       1                                        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00              113803   53.1000             C123        S
# 4              5         0       3                                                            Allen, Mr. William Henry    male  35.00              373450    8.0500              NaN        S
# 5              6         0       3                                                                    Moran, Mr. James    male    NaN              330877    8.4583              NaN        Q
# 6              7         0       1                                                             McCarthy, Mr. Timothy J    male  54.00               17463   51.8625              E46        S
# 7              8         0       3                                                       Palsson, Master Gosta Leonard    male   2.00              349909   21.0750              NaN        S
# 8              9         1       3                                   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.00              347742   11.1333              NaN        S
# 9             10         1       2                                                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.00              237736   30.0708              NaN        C
# 10            11         1       3                                                      Sandstrom, Miss Marguerite Rut  female   4.00             PP 9549   16.7000               G6        S
# 11            12         1       1                                                             Bonnell, Miss Elizabeth  female  58.00              113783   26.5500             C103        S
# 12            13         0       3                                                      Saundercock, Mr. William Henry    male  20.00           A/5. 2151    8.0500              NaN        S
# 13            14         0       3                                                         Andersson, Mr. Anders Johan    male  39.00              347082   31.2750              NaN        S
# 14            15         0       3                                                 Vestrom, Miss Hulda Amanda Adolfina  female  14.00              350406    7.8542              NaN        S
# 15            16         1       2                                                    Hewlett, Mrs. (Mary D Kingcome)   female  55.00              248706   16.0000              NaN        S
# 16            17         0       3                                                                 Rice, Master Eugene    male   2.00              382652   29.1250              NaN        Q
# 17            18         1       2                                                        Williams, Mr. Charles Eugene    male    NaN              244373   13.0000              NaN        S
# 18            19         0       3                             Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)  female  31.00              345763   18.0000              NaN        S
# 19            20         1       3                                                             Masselmani, Mrs. Fatima  female    NaN                2649    7.2250              NaN        C
# 20            21         0       2                                                                Fynney, Mr. Joseph J    male  35.00              239865   26.0000              NaN        S
# 21            22         1       2                                                               Beesley, Mr. Lawrence    male  34.00              248698   13.0000              D56        S
# 22            23         1       3                                                          McGowan, Miss Anna "Annie"  female  15.00              330923    8.0292              NaN        Q
# 23            24         1       1                                                        Sloper, Mr. William Thompson    male  28.00              113788   35.5000               A6        S
# 24            25         0       3                                                        Palsson, Miss Torborg Danira  female   8.00              349909   21.0750              NaN        S
# 25            26         1       3                           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)  female  38.00              347077   31.3875              NaN        S
# 26            27         0       3                                                             Emir, Mr. Farred Chehab    male    NaN                2631    7.2250              NaN        C
# 27            28         0       1                                                      Fortune, Mr. Charles Alexander    male  19.00               19950  263.0000      C23 C25 C27        S
# 28            29         1       3                                                        O'Dwyer, Miss Ellen "Nellie"  female    NaN              330959    7.8792              NaN        Q
# 29            30         0       3                                                                 Todoroff, Mr. Lalio    male    NaN              349216    7.8958              NaN        S
# 30            31         0       1                                                            Uruchurtu, Don. Manuel E    male  40.00            PC 17601   27.7208              NaN        C
# 31            32         1       1                                      Spencer, Mrs. William Augustus (Marie Eugenie)  female    NaN            PC 17569  146.5208              B78        C
# 32            33         1       3                                                             Glynn, Miss Mary Agatha  female    NaN              335677    7.7500              NaN        Q
# 33            34         0       2                                                               Wheadon, Mr. Edward H    male  66.00          C.A. 24579   10.5000              NaN        S
# 34            35         0       1                                                             Meyer, Mr. Edgar Joseph    male  28.00            PC 17604   82.1708              NaN        C
# 35            36         0       1                                                      Holverson, Mr. Alexander Oskar    male  42.00              113789   52.0000              NaN        S
# 36            37         1       3                                                                    Mamee, Mr. Hanna    male    NaN                2677    7.2292              NaN        C
# 37            38         0       3                                                            Cann, Mr. Ernest Charles    male  21.00          A./5. 2152    8.0500              NaN        S
# 38            39         0       3                                                   Vander Planke, Miss Augusta Maria  female  18.00              345764   18.0000              NaN        S
# 39            40         1       3                                                          Nicola-Yarred, Miss Jamila  female  14.00                2651   11.2417              NaN        C
# 40            41         0       3                                      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.00                7546    9.4750              NaN        S
# 41            42         0       2                            Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)  female  27.00               11668   21.0000              NaN        S
# 42            43         0       3                                                                 Kraeff, Mr. Theodor    male    NaN              349253    7.8958              NaN        C
# 43            44         1       2                                             Laroche, Miss Simonne Marie Anne Andree  female   3.00       SC/Paris 2123   41.5792              NaN        C
# 44            45         1       3                                                        Devaney, Miss Margaret Delia  female  19.00              330958    7.8792              NaN        Q
# 45            46         0       3                                                            Rogers, Mr. William John    male    NaN     S.C./A.4. 23567    8.0500              NaN        S
# 46            47         0       3                                                                   Lennon, Mr. Denis    male    NaN              370371   15.5000              NaN        Q
# 47            48         1       3                                                            O'Driscoll, Miss Bridget  female    NaN               14311    7.7500              NaN        Q
# 48            49         0       3                                                                 Samaan, Mr. Youssef    male    NaN                2662   21.6792              NaN        C
# 49            50         0       3                                       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.00              349237   17.8000              NaN        S
# 50            51         0       3                                                           Panula, Master Juha Niilo    male   7.00             3101295   39.6875              NaN        S
# 51            52         0       3                                                        Nosworthy, Mr. Richard Cater    male  21.00          A/4. 39886    7.8000              NaN        S
# 52            53         1       1                                            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.00            PC 17572   76.7292              D33        C
# 53            54         1       2                                  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)  female  29.00                2926   26.0000              NaN        S
# 54            55         0       1                                                      Ostby, Mr. Engelhart Cornelius    male  65.00              113509   61.9792              B30        C
# 55            56         1       1                                                                   Woolner, Mr. Hugh    male    NaN               19947   35.5000              C52        S
# 56            57         1       2                                                                    Rugg, Miss Emily  female  21.00          C.A. 31026   10.5000              NaN        S
# 57            58         0       3                                                                 Novel, Mr. Mansouer    male  28.50                2697    7.2292              NaN        C
# 58            59         1       2                                                         West, Miss Constance Mirium  female   5.00          C.A. 34651   27.7500              NaN        S
# 59            60         0       3                                                   Goodwin, Master William Frederick    male  11.00             CA 2144   46.9000              NaN        S
# 60            61         0       3                                                               Sirayanian, Mr. Orsen    male  22.00                2669    7.2292              NaN        C
# 61            62         1       1                                                                  Icard, Miss Amelie  female  38.00              113572   80.0000              B28      NaN
# 62            63         0       1                                                         Harris, Mr. Henry Birkhardt    male  45.00               36973   83.4750              C83        S
# 63            64         0       3                                                                Skoog, Master Harald    male   4.00              347088   27.9000              NaN        S
# 64            65         0       1                                                               Stewart, Mr. Albert A    male    NaN            PC 17605   27.7208              NaN        C
# 65            66         1       3                                                             Moubarek, Master Gerios    male    NaN                2661   15.2458              NaN        C
# 66            67         1       2                                                        Nye, Mrs. (Elizabeth Ramell)  female  29.00          C.A. 29395   10.5000              F33        S
# 67            68         0       3                                                            Crease, Mr. Ernest James    male  19.00           S.P. 3464    8.1583              NaN        S
# 68            69         1       3                                                      Andersson, Miss Erna Alexandra  female  17.00             3101281    7.9250              NaN        S
# 69            70         0       3                                                                   Kink, Mr. Vincenz    male  26.00              315151    8.6625              NaN        S
# 70            71         0       2                                                          Jenkin, Mr. Stephen Curnow    male  32.00          C.A. 33111   10.5000              NaN        S
# 71            72         0       3                                                           Goodwin, Miss Lillian Amy  female  16.00             CA 2144   46.9000              NaN        S
# 72            73         0       2                                                                Hood, Mr. Ambrose Jr    male  21.00        S.O.C. 14879   73.5000              NaN        S
# 73            74         0       3                                                         Chronopoulos, Mr. Apostolos    male  26.00                2680   14.4542              NaN        C
# 74            75         1       3                                                                       Bing, Mr. Lee    male  32.00                1601   56.4958              NaN        S
# 75            76         0       3                                                             Moen, Mr. Sigurd Hansen    male  25.00              348123    7.6500            F G73        S
# 76            77         0       3                                                                   Staneff, Mr. Ivan    male    NaN              349208    7.8958              NaN        S
# 77            78         0       3                                                            Moutal, Mr. Rahamin Haim    male    NaN              374746    8.0500              NaN        S
# 78            79         1       2                                                        Caldwell, Master Alden Gates    male   0.83              248738   29.0000              NaN        S
# 79            80         1       3                                                             Dowdell, Miss Elizabeth  female  30.00              364516   12.4750              NaN        S
# 80            81         0       3                                                                Waelens, Mr. Achille    male  22.00              345767    9.0000              NaN        S
# 81            82         1       3                                                         Sheerlinck, Mr. Jan Baptist    male  29.00              345779    9.5000              NaN        S
# 82            83         1       3                                                       McDermott, Miss Brigdet Delia  female    NaN              330932    7.7875              NaN        Q
# 83            84         0       1                                                             Carrau, Mr. Francisco M    male  28.00              113059   47.1000              NaN        S
# 84            85         1       2                                                                  Ilett, Miss Bertha  female  17.00          SO/C 14885   10.5000              NaN        S
# 85            86         1       3                             Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)  female  33.00             3101278   15.8500              NaN        S
# 86            87         0       3                                                              Ford, Mr. William Neal    male  16.00          W./C. 6608   34.3750              NaN        S
# 87            88         0       3                                                       Slocovski, Mr. Selman Francis    male    NaN     SOTON/OQ 392086    8.0500              NaN        S
# 88            89         1       1                                                           Fortune, Miss Mabel Helen  female  23.00               19950  263.0000      C23 C25 C27        S
# 89            90         0       3                                                              Celotti, Mr. Francesco    male  24.00              343275    8.0500              NaN        S
# 90            91         0       3                                                                Christmann, Mr. Emil    male  29.00              343276    8.0500              NaN        S
# 91            92         0       3                                                          Andreasson, Mr. Paul Edvin    male  20.00              347466    7.8542              NaN        S
# 92            93         0       1                                                         Chaffee, Mr. Herbert Fuller    male  46.00         W.E.P. 5734   61.1750              E31        S
# 93            94         0       3                                                             Dean, Mr. Bertram Frank    male  26.00           C.A. 2315   20.5750              NaN        S
# 94            95         0       3                                                                   Coxon, Mr. Daniel    male  59.00              364500    7.2500              NaN        S
# 95            96         0       3                                                         Shorney, Mr. Charles Joseph    male    NaN              374910    8.0500              NaN        S
# 96            97         0       1                                                           Goldschmidt, Mr. George B    male  71.00            PC 17754   34.6542               A5        C
# 97            98         1       1                                                     Greenfield, Mr. William Bertram    male  23.00            PC 17759   63.3583          D10 D12        C
# 98            99         1       2                                                Doling, Mrs. John T (Ada Julia Bone)  female  34.00              231919   23.0000              NaN        S
# 99           100         0       2                                                                   Kantor, Mr. Sinai    male  34.00              244367   26.0000              NaN        S
# 100          101         0       3                                                              Petranec, Miss Matilda  female  28.00              349245    7.8958              NaN        S
# 101          102         0       3                                                    Petroff, Mr. Pastcho ("Pentcho")    male    NaN              349215    7.8958              NaN        S
# 102          103         0       1                                                           White, Mr. Richard Frasar    male  21.00               35281   77.2875              D26        S
# 103          104         0       3                                                          Johansson, Mr. Gustaf Joel    male  33.00                7540    8.6542              NaN        S
# 104          105         0       3                                                      Gustafsson, Mr. Anders Vilhelm    male  37.00             3101276    7.9250              NaN        S
# 105          106         0       3                                                               Mionoff, Mr. Stoytcho    male  28.00              349207    7.8958              NaN        S
# 106          107         1       3                                                     Salkjelsvik, Miss Anna Kristine  female  21.00              343120    7.6500              NaN        S
# 107          108         1       3                                                              Moss, Mr. Albert Johan    male    NaN              312991    7.7750              NaN        S
# 108          109         0       3                                                                     Rekic, Mr. Tido    male  38.00              349249    7.8958              NaN        S
# 109          110         1       3                                                                  Moran, Miss Bertha  female    NaN              371110   24.1500              NaN        Q
# 110          111         0       1                                                      Porter, Mr. Walter Chamberlain    male  47.00              110465   52.0000             C110        S
# 111          112         0       3                                                                 Zabour, Miss Hileni  female  14.50                2665   14.4542              NaN        C
# 112          113         0       3                                                              Barton, Mr. David John    male  22.00              324669    8.0500              NaN        S
# 113          114         0       3                                                              Jussila, Miss Katriina  female  20.00                4136    9.8250              NaN        S
# 114          115         0       3                                                                Attalah, Miss Malake  female  17.00                2627   14.4583              NaN        C
# 115          116         0       3                                                               Pekoniemi, Mr. Edvard    male  21.00   STON/O 2. 3101294    7.9250              NaN        S
# 116          117         0       3                                                                Connors, Mr. Patrick    male  70.50              370369    7.7500              NaN        Q
# 117          118         0       2                                                     Turpin, Mr. William John Robert    male  29.00               11668   21.0000              NaN        S
# 118          119         0       1                                                            Baxter, Mr. Quigg Edmond    male  24.00            PC 17558  247.5208          B58 B60        C
# 119          120         0       3                                                    Andersson, Miss Ellis Anna Maria  female   2.00              347082   31.2750              NaN        S
# 120          121         0       2                                                         Hickman, Mr. Stanley George    male  21.00        S.O.C. 14879   73.5000              NaN        S
# 121          122         0       3                                                          Moore, Mr. Leonard Charles    male    NaN           A4. 54510    8.0500              NaN        S
# 122          123         0       2                                                                Nasser, Mr. Nicholas    male  32.50              237736   30.0708              NaN        C
# 123          124         1       2                                                                  Webber, Miss Susan  female  32.50               27267   13.0000             E101        S
# 124          125         0       1                                                         White, Mr. Percival Wayland    male  54.00               35281   77.2875              D26        S
# 125          126         1       3                                                         Nicola-Yarred, Master Elias    male  12.00                2651   11.2417              NaN        C
# 126          127         0       3                                                                 McMahon, Mr. Martin    male    NaN              370372    7.7500              NaN        Q
# 127          128         1       3                                                           Madsen, Mr. Fridtjof Arne    male  24.00             C 17369    7.1417              NaN        S
# 128          129         1       3                                                                    Peter, Miss Anna  female    NaN                2668   22.3583            F E69        C
# 129          130         0       3                                                                  Ekstrom, Mr. Johan    male  45.00              347061    6.9750              NaN        S
# 130          131         0       3                                                                Drazenoic, Mr. Jozef    male  33.00              349241    7.8958              NaN        C
# 131          132         0       3                                                      Coelho, Mr. Domingos Fernandeo    male  20.00  SOTON/O.Q. 3101307    7.0500              NaN        S
# 132          133         0       3                                      Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.00           A/5. 3337   14.5000              NaN        S
# 133          134         1       2                                       Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.00              228414   26.0000              NaN        S
# 134          135         0       2                                                      Sobey, Mr. Samuel James Hayden    male  25.00          C.A. 29178   13.0000              NaN        S
# 135          136         0       2                                                                  Richard, Mr. Emile    male  23.00       SC/PARIS 2133   15.0458              NaN        C
# 136          137         1       1                                                         Newsom, Miss Helen Monypeny  female  19.00               11752   26.2833              D47        S
# 137          138         0       1                                                         Futrelle, Mr. Jacques Heath    male  37.00              113803   53.1000             C123        S
# 138          139         0       3                                                                 Osen, Mr. Olaf Elon    male  16.00                7534    9.2167              NaN        S
# 139          140         0       1                                                                  Giglio, Mr. Victor    male  24.00            PC 17593   79.2000              B86        C
# 140          141         0       3                                                       Boulos, Mrs. Joseph (Sultana)  female    NaN                2678   15.2458              NaN        C
# 141          142         1       3                                                             Nysten, Miss Anna Sofia  female  22.00              347081    7.7500              NaN        S
# 142          143         1       3                                Hakkarainen, Mrs. Pekka Pietari (Elin Matilda Dolck)  female  24.00    STON/O2. 3101279   15.8500              NaN        S
# 143          144         0       3                                                                 Burke, Mr. Jeremiah    male  19.00              365222    6.7500              NaN        Q
# 144          145         0       2                                                          Andrew, Mr. Edgardo Samuel    male  18.00              231945   11.5000              NaN        S
# 145          146         0       2                                                        Nicholls, Mr. Joseph Charles    male  19.00          C.A. 33112   36.7500              NaN        S
# 146          147         1       3                                        Andersson, Mr. August Edvard ("Wennerstrom")    male  27.00              350043    7.7958              NaN        S
# 147          148         0       3                                                     Ford, Miss Robina Maggie "Ruby"  female   9.00          W./C. 6608   34.3750              NaN        S
# 148          149         0       2                                            Navratil, Mr. Michel ("Louis M Hoffman")    male  36.50              230080   26.0000               F2        S
# 149          150         0       2                                                   Byles, Rev. Thomas Roussel Davids    male  42.00              244310   13.0000              NaN        S
# 150          151         0       2                                                          Bateman, Rev. Robert James    male  51.00         S.O.P. 1166   12.5250              NaN        S
# 151          152         1       1                                                   Pears, Mrs. Thomas (Edith Wearne)  female  22.00              113776   66.6000               C2        S
# 152          153         0       3                                                                    Meo, Mr. Alfonzo    male  55.50          A.5. 11206    8.0500              NaN        S
# 153          154         0       3                                                     van Billiard, Mr. Austin Blyler    male  40.50            A/5. 851   14.5000              NaN        S
# 154          155         0       3                                                               Olsen, Mr. Ole Martin    male    NaN           Fa 265302    7.3125              NaN        S
# 155          156         0       1                                                         Williams, Mr. Charles Duane    male  51.00            PC 17597   61.3792              NaN        C
# 156          157         1       3                                                     Gilnagh, Miss Katherine "Katie"  female  16.00               35851    7.7333              NaN        Q
# 157          158         0       3                                                                     Corn, Mr. Harry    male  30.00     SOTON/OQ 392090    8.0500              NaN        S
# 158          159         0       3                                                                 Smiljanic, Mr. Mile    male    NaN              315037    8.6625              NaN        S
# 159          160         0       3                                                           Sage, Master Thomas Henry    male    NaN            CA. 2343   69.5500              NaN        S
# 160          161         0       3                                                            Cribb, Mr. John Hatfield    male  44.00              371362   16.1000              NaN        S
# 161          162         1       2                                  Watt, Mrs. James (Elizabeth "Bessie" Inglis Milne)  female  40.00          C.A. 33595   15.7500              NaN        S
# 162          163         0       3                                                          Bengtsson, Mr. John Viktor    male  26.00              347068    7.7750              NaN        S
# 163          164         0       3                                                                     Calic, Mr. Jovo    male  17.00              315093    8.6625              NaN        S
# 164          165         0       3                                                         Panula, Master Eino Viljami    male   1.00             3101295   39.6875              NaN        S
# 165          166         1       3                                      Goldsmith, Master Frank John William "Frankie"    male   9.00              363291   20.5250              NaN        S
# 166          167         1       1                                              Chibnall, Mrs. (Edith Martha Bowerman)  female    NaN              113505   55.0000              E33        S
# 167          168         0       3                                     Skoog, Mrs. William (Anna Bernhardina Karlsson)  female  45.00              347088   27.9000              NaN        S
# 168          169         0       1                                                                 Baumann, Mr. John D    male    NaN            PC 17318   25.9250              NaN        S
# 169          170         0       3                                                                       Ling, Mr. Lee    male  28.00                1601   56.4958              NaN        S
# 170          171         0       1                                                           Van der hoef, Mr. Wyckoff    male  61.00              111240   33.5000              B19        S
# 171          172         0       3                                                                 Rice, Master Arthur    male   4.00              382652   29.1250              NaN        Q
# 172          173         1       3                                                         Johnson, Miss Eleanor Ileen  female   1.00              347742   11.1333              NaN        S
# 173          174         0       3                                                           Sivola, Mr. Antti Wilhelm    male  21.00   STON/O 2. 3101280    7.9250              NaN        S
# 174          175         0       1                                                             Smith, Mr. James Clinch    male  56.00               17764   30.6958               A7        C
# 175          176         0       3                                                              Klasen, Mr. Klas Albin    male  18.00              350404    7.8542              NaN        S
# 176          177         0       3                                                        Lefebre, Master Henry Forbes    male    NaN                4133   25.4667              NaN        S
# 177          178         0       1                                                           Isham, Miss Ann Elizabeth  female  50.00            PC 17595   28.7125              C49        C
# 178          179         0       2                                                                  Hale, Mr. Reginald    male  30.00              250653   13.0000              NaN        S
# 179          180         0       3                                                                 Leonard, Mr. Lionel    male  36.00                LINE    0.0000              NaN        S
# 180          181         0       3                                                         Sage, Miss Constance Gladys  female    NaN            CA. 2343   69.5500              NaN        S
# 181          182         0       2                                                                    Pernot, Mr. Rene    male    NaN       SC/PARIS 2131   15.0500              NaN        C
# 182          183         0       3                                                Asplund, Master Clarence Gustaf Hugo    male   9.00              347077   31.3875              NaN        S
# 183          184         1       2                                                            Becker, Master Richard F    male   1.00              230136   39.0000               F4        S
# 184          185         1       3                                                  Kink-Heilmann, Miss Luise Gretchen  female   4.00              315153   22.0250              NaN        S
# 185          186         0       1                                                               Rood, Mr. Hugh Roscoe    male    NaN              113767   50.0000              A32        S
# 186          187         1       3                                     O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)  female    NaN              370365   15.5000              NaN        Q
# 187          188         1       1                                       Romaine, Mr. Charles Hallace ("Mr C Rolmane")    male  45.00              111428   26.5500              NaN        S
# 188          189         0       3                                                                    Bourke, Mr. John    male  40.00              364849   15.5000              NaN        Q
# 189          190         0       3                                                                 Turcin, Mr. Stjepan    male  36.00              349247    7.8958              NaN        S
# 190          191         1       2                                                                 Pinsky, Mrs. (Rosa)  female  32.00              234604   13.0000              NaN        S
# 191          192         0       2                                                               Carbines, Mr. William    male  19.00               28424   13.0000              NaN        S
# 192          193         1       3                                      Andersen-Jensen, Miss Carla Christine Nielsine  female  19.00              350046    7.8542              NaN        S
# 193          194         1       2                                                           Navratil, Master Michel M    male   3.00              230080   26.0000               F2        S
# 194          195         1       1                                           Brown, Mrs. James Joseph (Margaret Tobin)  female  44.00            PC 17610   27.7208               B4        C
# 195          196         1       1                                                                 Lurette, Miss Elise  female  58.00            PC 17569  146.5208              B80        C
# 196          197         0       3                                                                 Mernagh, Mr. Robert    male    NaN              368703    7.7500              NaN        Q
# 197          198         0       3                                                    Olsen, Mr. Karl Siegwart Andreas    male  42.00                4579    8.4042              NaN        S
# 198          199         1       3                                                     Madigan, Miss Margaret "Maggie"  female    NaN              370370    7.7500              NaN        Q
# 199          200         0       2                                               Yrois, Miss Henriette ("Mrs Harbeck")  female  24.00              248747   13.0000              NaN        S
# 200          201         0       3                                                      Vande Walle, Mr. Nestor Cyriel    male  28.00              345770    9.5000              NaN        S
# 201          202         0       3                                                                 Sage, Mr. Frederick    male    NaN            CA. 2343   69.5500              NaN        S
# 202          203         0       3                                                          Johanson, Mr. Jakob Alfred    male  34.00             3101264    6.4958              NaN        S
# 203          204         0       3                                                                Youseff, Mr. Gerious    male  45.50                2628    7.2250              NaN        C
# 204          205         1       3                                                            Cohen, Mr. Gurshon "Gus"    male  18.00            A/5 3540    8.0500              NaN        S
# 205          206         0       3                                                           Strom, Miss Telma Matilda  female   2.00              347054   10.4625               G6        S
# 206          207         0       3                                                          Backstrom, Mr. Karl Alfred    male  32.00             3101278   15.8500              NaN        S
# 207          208         1       3                                                         Albimona, Mr. Nassef Cassem    male  26.00                2699   18.7875              NaN        C
# 208          209         1       3                                                            Carr, Miss Helen "Ellen"  female  16.00              367231    7.7500              NaN        Q
# 209          210         1       1                                                                    Blank, Mr. Henry    male  40.00              112277   31.0000              A31        C
# 210          211         0       3                                                                      Ali, Mr. Ahmed    male  24.00  SOTON/O.Q. 3101311    7.0500              NaN        S
# 211          212         1       2                                                           Cameron, Miss Clear Annie  female  35.00        F.C.C. 13528   21.0000              NaN        S
# 212          213         0       3                                                              Perkin, Mr. John Henry    male  22.00           A/5 21174    7.2500              NaN        S
# 213          214         0       2                                                         Givard, Mr. Hans Kristensen    male  30.00              250646   13.0000              NaN        S
# 214          215         0       3                                                                 Kiernan, Mr. Philip    male    NaN              367229    7.7500              NaN        Q
# 215          216         1       1                                                              Newell, Miss Madeleine  female  31.00               35273  113.2750              D36        C
# 216          217         1       3                                                               Honkanen, Miss Eliina  female  27.00    STON/O2. 3101283    7.9250              NaN        S
# 217          218         0       2                                                        Jacobsohn, Mr. Sidney Samuel    male  42.00              243847   27.0000              NaN        S
# 218          219         1       1                                                                Bazzani, Miss Albina  female  32.00               11813   76.2917              D15        C
# 219          220         0       2                                                                  Harris, Mr. Walter    male  30.00           W/C 14208   10.5000              NaN        S
# 220          221         1       3                                                      Sunderland, Mr. Victor Francis    male  16.00     SOTON/OQ 392089    8.0500              NaN        S
# 221          222         0       2                                                                Bracken, Mr. James H    male  27.00              220367   13.0000              NaN        S
# 222          223         0       3                                                             Green, Mr. George Henry    male  51.00               21440    8.0500              NaN        S
# 223          224         0       3                                                                Nenkoff, Mr. Christo    male    NaN              349234    7.8958              NaN        S
# 224          225         1       1                                                        Hoyt, Mr. Frederick Maxfield    male  38.00               19943   90.0000              C93        S
# 225          226         0       3                                                        Berglund, Mr. Karl Ivar Sven    male  22.00             PP 4348    9.3500              NaN        S
# 226          227         1       2                                                           Mellors, Mr. William John    male  19.00           SW/PP 751   10.5000              NaN        S
# 227          228         0       3                                                     Lovell, Mr. John Hall ("Henry")    male  20.50           A/5 21173    7.2500              NaN        S
# 228          229         0       2                                                           Fahlstrom, Mr. Arne Jonas    male  18.00              236171   13.0000              NaN        S
# 229          230         0       3                                                              Lefebre, Miss Mathilde  female    NaN                4133   25.4667              NaN        S
# 230          231         1       1                                        Harris, Mrs. Henry Birkhardt (Irene Wallach)  female  35.00               36973   83.4750              C83        S
# 231          232         0       3                                                            Larsson, Mr. Bengt Edvin    male  29.00              347067    7.7750              NaN        S
# 232          233         0       2                                                           Sjostedt, Mr. Ernst Adolf    male  59.00              237442   13.5000              NaN        S
# 233          234         1       3                                                       Asplund, Miss Lillian Gertrud  female   5.00              347077   31.3875              NaN        S
# 234          235         0       2                                                   Leyson, Mr. Robert William Norman    male  24.00          C.A. 29566   10.5000              NaN        S
# 235          236         0       3                                                         Harknett, Miss Alice Phoebe  female    NaN          W./C. 6609    7.5500              NaN        S
# 236          237         0       2                                                                   Hold, Mr. Stephen    male  44.00               26707   26.0000              NaN        S
# 237          238         1       2                                                     Collyer, Miss Marjorie "Lottie"  female   8.00          C.A. 31921   26.2500              NaN        S
# 238          239         0       2                                                     Pengelly, Mr. Frederick William    male  19.00               28665   10.5000              NaN        S
# 239          240         0       2                                                              Hunt, Mr. George Henry    male  33.00          SCO/W 1585   12.2750              NaN        S
# 240          241         0       3                                                                Zabour, Miss Thamine  female    NaN                2665   14.4542              NaN        C
# 241          242         1       3                                                       Murphy, Miss Katherine "Kate"  female    NaN              367230   15.5000              NaN        Q
# 242          243         0       2                                                     Coleridge, Mr. Reginald Charles    male  29.00         W./C. 14263   10.5000              NaN        S
# 243          244         0       3                                                       Maenpaa, Mr. Matti Alexanteri    male  22.00   STON/O 2. 3101275    7.1250              NaN        S
# 244          245         0       3                                                                Attalah, Mr. Sleiman    male  30.00                2694    7.2250              NaN        C
# 245          246         0       1                                                         Minahan, Dr. William Edward    male  44.00               19928   90.0000              C78        Q
# 246          247         0       3                                                Lindahl, Miss Agda Thorilda Viktoria  female  25.00              347071    7.7750              NaN        S
# 247          248         1       2                                                     Hamalainen, Mrs. William (Anna)  female  24.00              250649   14.5000              NaN        S
# 248          249         1       1                                                       Beckwith, Mr. Richard Leonard    male  37.00               11751   52.5542              D35        S
# 249          250         0       2                                                       Carter, Rev. Ernest Courtenay    male  54.00              244252   26.0000              NaN        S
# 250          251         0       3                                                              Reed, Mr. James George    male    NaN              362316    7.2500              NaN        S
# ...
# 807          808         0       3                                                      Pettersson, Miss Ellen Natalia  female  18.00              347087    7.7750              NaN        S
# 808          809         0       2                                                                   Meyer, Mr. August    male  39.00              248723   13.0000              NaN        S
# 809          810         1       1                                      Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.00              113806   53.1000               E8        S
# 810          811         0       3                                                              Alexander, Mr. William    male  26.00                3474    7.8875              NaN        S
# 811          812         0       3                                                                   Lester, Mr. James    male  39.00           A/4 48871   24.1500              NaN        S
# 812          813         0       2                                                           Slemen, Mr. Richard James    male  35.00               28206   10.5000              NaN        S
# 813          814         0       3                                                   Andersson, Miss Ebba Iris Alfrida  female   6.00              347082   31.2750              NaN        S
# 814          815         0       3                                                          Tomlin, Mr. Ernest Portage    male  30.50              364499    8.0500              NaN        S
# 815          816         0       1                                                                    Fry, Mr. Richard    male    NaN              112058    0.0000             B102        S
# 816          817         0       3                                                         Heininen, Miss Wendla Maria  female  23.00    STON/O2. 3101290    7.9250              NaN        S
# 817          818         0       2                                                                  Mallet, Mr. Albert    male  31.00     S.C./PARIS 2079   37.0042              NaN        C
# 818          819         0       3                                                    Holm, Mr. John Fredrik Alexander    male  43.00              C 7075    6.4500              NaN        S
# 819          820         0       3                                                         Skoog, Master Karl Thorsten    male  10.00              347088   27.9000              NaN        S
# 820          821         1       1                                  Hays, Mrs. Charles Melville (Clara Jennings Gregg)  female  52.00               12749   93.5000              B69        S
# 821          822         1       3                                                                   Lulic, Mr. Nikola    male  27.00              315098    8.6625              NaN        S
# 822          823         0       1                                                     Reuchlin, Jonkheer. John George    male  38.00               19972    0.0000              NaN        S
# 823          824         1       3                                                                  Moor, Mrs. (Beila)  female  27.00              392096   12.4750             E121        S
# 824          825         0       3                                                         Panula, Master Urho Abraham    male   2.00             3101295   39.6875              NaN        S
# 825          826         0       3                                                                     Flynn, Mr. John    male    NaN              368323    6.9500              NaN        Q
# 826          827         0       3                                                                        Lam, Mr. Len    male    NaN                1601   56.4958              NaN        S
# 827          828         1       2                                                                Mallet, Master Andre    male   1.00     S.C./PARIS 2079   37.0042              NaN        C
# 828          829         1       3                                                        McCormack, Mr. Thomas Joseph    male    NaN              367228    7.7500              NaN        Q
# 829          830         1       1                                           Stone, Mrs. George Nelson (Martha Evelyn)  female  62.00              113572   80.0000              B28      NaN
# 830          831         1       3                                             Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.00                2659   14.4542              NaN        C
# 831          832         1       2                                                      Richards, Master George Sibley    male   0.83               29106   18.7500              NaN        S
# 832          833         0       3                                                                      Saad, Mr. Amin    male    NaN                2671    7.2292              NaN        C
# 833          834         0       3                                                              Augustsson, Mr. Albert    male  23.00              347468    7.8542              NaN        S
# 834          835         0       3                                                              Allum, Mr. Owen George    male  18.00                2223    8.3000              NaN        S
# 835          836         1       1                                                          Compton, Miss Sara Rebecca  female  39.00            PC 17756   83.1583              E49        C
# 836          837         0       3                                                                    Pasic, Mr. Jakob    male  21.00              315097    8.6625              NaN        S
# 837          838         0       3                                                                 Sirota, Mr. Maurice    male    NaN              392092    8.0500              NaN        S
# 838          839         1       3                                                                     Chip, Mr. Chang    male  32.00                1601   56.4958              NaN        S
# 839          840         1       1                                                                Marechal, Mr. Pierre    male    NaN               11774   29.7000              C47        C
# 840          841         0       3                                                         Alhomaki, Mr. Ilmari Rudolf    male  20.00    SOTON/O2 3101287    7.9250              NaN        S
# 841          842         0       2                                                            Mudd, Mr. Thomas Charles    male  16.00         S.O./P.P. 3   10.5000              NaN        S
# 842          843         1       1                                                              Serepeca, Miss Augusta  female  30.00              113798   31.0000              NaN        C
# 843          844         0       3                                                          Lemberopolous, Mr. Peter L    male  34.50                2683    6.4375              NaN        C
# 844          845         0       3                                                                 Culumovic, Mr. Jeso    male  17.00              315090    8.6625              NaN        S
# 845          846         0       3                                                                 Abbing, Mr. Anthony    male  42.00           C.A. 5547    7.5500              NaN        S
# 846          847         0       3                                                            Sage, Mr. Douglas Bullen    male    NaN            CA. 2343   69.5500              NaN        S
# 847          848         0       3                                                                  Markoff, Mr. Marin    male  35.00              349213    7.8958              NaN        C
# 848          849         0       2                                                                   Harper, Rev. John    male  28.00              248727   33.0000              NaN        S
# 849          850         1       1                                        Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female    NaN               17453   89.1042              C92        C
# 850          851         0       3                                              Andersson, Master Sigvard Harald Elias    male   4.00              347082   31.2750              NaN        S
# 851          852         0       3                                                                 Svensson, Mr. Johan    male  74.00              347060    7.7750              NaN        S
# 852          853         0       3                                                              Boulos, Miss Nourelain  female   9.00                2678   15.2458              NaN        C
# 853          854         1       1                                                            Lines, Miss Mary Conover  female  16.00            PC 17592   39.4000              D28        S
# 854          855         0       2                                       Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44.00              244252   26.0000              NaN        S
# 855          856         1       3                                                          Aks, Mrs. Sam (Leah Rosen)  female  18.00              392091    9.3500              NaN        S
# 856          857         1       1                                          Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.00               36928  164.8667              NaN        S
# 857          858         1       1                                                              Daly, Mr. Peter Denis     male  51.00              113055   26.5500              E17        S
# 858          859         1       3                                               Baclini, Mrs. Solomon (Latifa Qurban)  female  24.00                2666   19.2583              NaN        C
# 859          860         0       3                                                                    Razi, Mr. Raihed    male    NaN                2629    7.2292              NaN        C
# 860          861         0       3                                                             Hansen, Mr. Claus Peter    male  41.00              350026   14.1083              NaN        S
# 861          862         0       2                                                         Giles, Mr. Frederick Edward    male  21.00               28134   11.5000              NaN        S
# 862          863         1       1                                 Swift, Mrs. Frederick Joel (Margaret Welles Barron)  female  48.00               17466   25.9292              D17        S
# 863          864         0       3                                                    Sage, Miss Dorothy Edith "Dolly"  female    NaN            CA. 2343   69.5500              NaN        S
# 864          865         0       2                                                              Gill, Mr. John William    male  24.00              233866   13.0000              NaN        S
# 865          866         1       2                                                            Bystrom, Mrs. (Karolina)  female  42.00              236852   13.0000              NaN        S
# 866          867         1       2                                                         Duran y More, Miss Asuncion  female  27.00       SC/PARIS 2149   13.8583              NaN        C
# 867          868         0       1                                                Roebling, Mr. Washington Augustus II    male  31.00            PC 17590   50.4958              A24        S
# 868          869         0       3                                                         van Melkebeke, Mr. Philemon    male    NaN              345777    9.5000              NaN        S
# 869          870         1       3                                                      Johnson, Master Harold Theodor    male   4.00              347742   11.1333              NaN        S
# 870          871         0       3                                                                   Balkic, Mr. Cerin    male  26.00              349248    7.8958              NaN        S
# 871          872         1       1                                    Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.00               11751   52.5542              D35        S
# 872          873         0       1                                                            Carlsson, Mr. Frans Olof    male  33.00                 695    5.0000      B51 B53 B55        S
# 873          874         0       3                                                         Vander Cruyssen, Mr. Victor    male  47.00              345765    9.0000              NaN        S
# 874          875         1       2                                               Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.00           P/PP 3381   24.0000              NaN        C
# 875          876         1       3                                                     Najib, Miss Adele Kiamie "Jane"  female  15.00                2667    7.2250              NaN        C
# 876          877         0       3                                                       Gustafsson, Mr. Alfred Ossian    male  20.00                7534    9.8458              NaN        S
# 877          878         0       3                                                                Petroff, Mr. Nedelio    male  19.00              349212    7.8958              NaN        S
# 878          879         0       3                                                                  Laleff, Mr. Kristo    male    NaN              349217    7.8958              NaN        S
# 879          880         1       1                                       Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.00               11767   83.1583              C50        C
# 880          881         1       2                                        Shelley, Mrs. William (Imanita Parrish Hall)  female  25.00              230433   26.0000              NaN        S
# 881          882         0       3                                                                  Markun, Mr. Johann    male  33.00              349257    7.8958              NaN        S
# 882          883         0       3                                                         Dahlberg, Miss Gerda Ulrika  female  22.00                7552   10.5167              NaN        S
# 883          884         0       2                                                       Banfield, Mr. Frederick James    male  28.00    C.A./SOTON 34068   10.5000              NaN        S
# 884          885         0       3                                                              Sutehall, Mr. Henry Jr    male  25.00     SOTON/OQ 392076    7.0500              NaN        S
# 885          886         0       3                                                Rice, Mrs. William (Margaret Norton)  female  39.00              382652   29.1250              NaN        Q
# 886          887         0       2                                                               Montvila, Rev. Juozas    male  27.00              211536   13.0000              NaN        S
# 887          888         1       1                                                         Graham, Miss Margaret Edith  female  19.00              112053   30.0000              B42        S
# 888          889         0       3                                             Johnston, Miss Catherine Helen "Carrie"  female    NaN          W./C. 6607   23.4500              NaN        S
# 889          890         1       1                                                               Behr, Mr. Karl Howell    male  26.00              111369   30.0000             C148        C
# 890          891         0       3                                                                 Dooley, Mr. Patrick    male  32.00              370376    7.7500              NaN        Q

# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.1

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
print(myvar[0])
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64
# 1

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
print(myvar["y"])
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# 7

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories, index = ["day1", "day2"])

print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %% [markdown]
# ***
# ## Creating pandas data structures
#
# Pandas has two main data structures:
#
# 1.  [`Series`](https://pandas.pydata.org/docs/reference/series.html)
#     represents observations of a *single* variable.
# 2.  [`DataFrame`](https://pandas.pydata.org/docs/reference/frame.html)
#     is a container for *several* variables. You can think
#     of each individual column of a `DataFrame` as a `Series`,
#     and each row represents one observation.
#
# The easiest way to create a `Series` or `DataFrame` is to create
# them from pre-existing data.
#
# To access pandas data structures and routines, we need to import them first.
# The near-universal convention is to make pandas available using the name `pd`:
# ```python
# import pandas as pd
# ```

# %% [markdown]
# *Example: Create Series from 1-dimensional NumPy array*

# %%
import numpy as np
import pandas as pd             # universal convention: import using pd

data = np.arange(5, 10)

# Create pandas Series from 1d array
pd.Series(data)
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# dtype: int64

# %% [markdown]
# *Example: Create DataFrame from NumPy array*
#
# We can create a `DataFrame` from a NumPy array:

# %%
# Create matrix of data
data = np.arange(15).reshape((-1, 3))

# Define variable (or column) names
varnames = ['A', 'B', 'C']

# Create pandas DataFrame from matrix
pd.DataFrame(data, columns=varnames)
# Out:
#     A   B   C
# 0   0   1   2
# 1   3   4   5
# 2   6   7   8
# 3   9  10  11
# 4  12  13  14

# %% [markdown]
# This code creates a `DataFrame` of three variables called `A`, `B` and `C`
# with 5 observations each.

# %% [markdown]
# *Example: Create DataFrame from dictionary*
#
# Alternatively, we can create a `DataFrame` from non-homogenous data as follows:

# %%
# Names (strings)
names = ['Alice', 'Bob']

# Birth dates (datetime objects)
bdates = pd.to_datetime(['1985-01-01', '1997-05-12'])

# Incomes (floats)
incomes = np.array([600000, np.nan])         # code missing income as NaN

# create DataFrame from dictionary
pd.DataFrame({'Name': names, 'Birthdate': bdates, 'Income': incomes})
# Out:
#     Name  Birthdate    Income
# 0  Alice 1985-01-01  600000.0
# 1    Bob 1997-05-12       NaN

# %% [markdown]
# If data types differ across columns, as in the above example,
# it is often convenient to create the `DataFrame` by passing
# a dictionary as an argument. Each key represents a column name
# and each corresponding value contains the data for that variable.

# %% [markdown]
# ***
# ## Importing data

# %% [markdown]
# ### Loading data with NumPy & its limitations

# %% [markdown]
# We often use files that store data
# as text files containing character-separated values (CSV) since virtually
# any application supports this data format.
# The most important functions to read text data are:
#
# -   [`np.loadtxt()`](https://numpy.org/doc/stable/reference/generated/numpy.loadtxt.html):     load data from a text file.
# -   [`np.genfromtxt()`](https://numpy.org/doc/stable/reference/generated/numpy.genfromtxt.html):
#     load data from a text file and handle missing data.
#
# There are a few other input/output functions in NumPy, for example to
# write arrays as raw binary data.
# We won't cover them here, but you can find them in the
# [official documentation](https://numpy.org/doc/stable/reference/routines.io.html).

# %% [markdown]
# *Example: Load character-separated text data*
#
# Consider the following tabular data from [FRED](https://fred.stlouisfed.org/) stored in the file
# [FRED_annual.csv](../../data/FRED/FRED_annual.csv) where the first two rows
# look as follows:
#
# | Year |  GDP   |  CPI | UNRATE | FEDFUNDS | INFLATION |
# | ---- | ------ | ---- | ------ | -------- | --------- |
# | 1954 | 2877.7 | 26.9 | 5.6    | 1.0      |           |
# | 1955 | 3083.0 | 26.8 | 4.4    | 1.8      | -0.4      |
#
# Note that the inflation column does has a missing value for the year 1954.
#
# These data are stored as character-separated values (CSV).
# To load this CSV file as a NumPy array, we use [`loadtxt()`]((https://numpy.org/doc/stable/reference/generated/numpy.loadtxt.html)).
# It is advantageous to globally set the path to the `data/` directory that can point either to the local directory or to the `data/` directory on GitHub.

# %%
# Uncomment this to use files in the local data/ directory
DATA_PATH = '../../data'

# Load data directly from GitHub
# DATA_PATH = 'https://raw.githubusercontent.com/richardfoltyn/TECH2-H25/main/data'

# %%
import numpy as np

# Path to CSV file
file = f'{DATA_PATH}/FRED/FRED_annual.csv'

# load CSV, skip header row and first row with missing data
data = np.loadtxt(file, skiprows=2, delimiter=',')

data[:2]        # Display first two rows
# Out:
# array([[ 1.9550e+03,  3.0830e+03,  2.6800e+01,  4.4000e+00,  1.8000e+00,
#         -4.0000e-01],
#        [ 1.9560e+03,  3.1488e+03,  2.7200e+01,  4.1000e+00,  2.7000e+00,
#          1.5000e+00]])

# %% [markdown]
# The default settings will in many cases be appropriate to load
# whatever CSV file we might have. However, we'll occasionally
# want to specify the following arguments to override the defaults:
#
# -   `delimiter`: Character used to separate individual fields (default: space).
# -   `skiprows=n`: Skip the first `n` rows. For example, if the CSV file
#     contains a header with variable names, `skiprows=1` needs to be
#     specified as NumPy by default cannot process these names.
# -   `encoding`: Set the character encoding of the input data. This
#     is usually not needed, but can be required to import data
#     with non-latin characters that are not encoded using Unicode.
#
# While `loadtxt()` is simple to use, it quickly reaches its limits
# with more complex data sets.
# For example, when we try to load the FRED data set including the first data row, we get the following error:

# %%
# Attempt to load CSV
data = np.loadtxt(file, skiprows=1, delimiter=',')
# Out:
# ValueError: could not convert string '' to float64 at row 0, column 6.

# %% [markdown]
# This code fails because `loadtxt()` does not support files with missing values. One can use the more flexible function [`np.genfromtxt()`](https://numpy.org/doc/stable/reference/generated/numpy.genfromtxt.html) which allows us to parse files with missing values:

# %%
# Load CSV file using genfromtxt() instead of loadtxt()
data = np.genfromtxt(file, skip_header=True, delimiter=',')

# Display first rows
data[:1]
# Out:
# array([[1.9540e+03, 2.8777e+03, 2.6900e+01, 5.6000e+00, 1.0000e+00,
#                nan]])

# %% [markdown]
# However, it is usually not worthwhile to figure out how to load complex data with NumPy as this is much easier with pandas.

# %% [markdown]
# ***
# ### Loading data with Pandas
#
# Pandas's input/output routines are more powerful than those implemented in NumPy:
#
# -   They support reading and writing numerous file formats.
# -   They support heterogeneous data without having to specify
#     the data type in advance.
# -   They gracefully handle missing values.
#
# For these reasons, it is often preferable to directly use pandas to
# process data instead of NumPy.
#
# The most important functions are:
#
# -   [`read_csv()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html),
#     [`to_csv()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html):
#     Read or write CSV text files.
# -   [`read_fwf()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_fwf.html):
#     Read data with fixed field widths, i.e., text data
#     that does not use delimiters to separate fields.
# -   [`read_excel()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html),
#     [`to_excel()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_excel.html):
#     Read or write Excel spreadsheets.
# -   [`read_stata()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_stata.html),
#     [`to_stata()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_stata.html):
#     Read or write Stata's `.dta` files.
#
# For a complete list of I/O routines, see the [official documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html).
#
# To illustrate, we repeat the above examples using pandas's
# [`read_csv()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html):

# %%
import pandas as pd

# Path to CSV file
file = f'{DATA_PATH}/FRED/FRED_annual.csv'

df = pd.read_csv(file, sep=',')
df.head(2)          # Display the first 2 rows of data
# Out:
#    Year     GDP   CPI  UNRATE  FEDFUNDS  INFLATION
# 0  1954  2877.7  26.9     5.6       1.0        NaN
# 1  1955  3083.0  26.8     4.4       1.8       -0.4

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# Use the pandas functions listed above to import data from the following files located in the <TT>data</TT> folder:
# <ol>
#     <li>titanic.csv</li>
#     <li>FRED/FRED_annual.xlsx</li>
# </ol>
#
# To load Excel files, you need to have the package <TT>openpyxl</TT> installed.
# </div>

# %%
import pandas as pd

# Path to CSV file
file = 'C:/Users/Bruker/OneDrive - Norwegian School of Economics/TECH2/TECH2-H25/data/titanic.csv'

# Load into DataFrame
df_titanic = pd.read_csv(file, sep =',')

print(df_titanic.head(2))

# %%
import pandas as pd

# Path to excel file
file = 'C:/Users/Bruker/OneDrive - Norwegian School of Economics/TECH2/TECH2-H25/data/FRED/FRED_annual.xlsx'

# Load into DataFrame
df = pd.read_excel(file)

print(df.head(2))
# Out:
#    Year     GDP   CPI  UNRATE  FEDFUNDS  INFLATION
# 0  1954  2877.7  26.9     5.6       1.0        NaN
# 1  1955  3083.0  26.8     4.4       1.8  -0.371747

# %% [markdown]
# ***
# ## Viewing data
#
# With large data sets, you hardly ever want to print the entire `DataFrame`.
# Pandas by default limits the amount of data shown. You can
# use the [`head()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html)
# and [`tail()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.tail.html)
# methods to explicitly display a specific
# number of rows from the top or the end of a `DataFrame`.
#
# To illustrate, we use a data set of passengers on board of the Titanic's
# maiden voyage stored in `titanic.csv` which contains the following columns:
#
# 1.  `PassengerId`
# 2.  `Survived`: indicator whether the person survived
# 3.  `Pclass`: accommodation class (first, second, third)
# 4.  `Name`: Name of passenger (last name, first name)
# 5.  `Sex`: `male` or `female`
# 6.  `Age`
# 7.  `Ticket`: Ticket number
# 8.  `Fare`: Fare in pounds
# 9.  `Cabin`: Deck + cabin number
# 10. `Embarked`: Port at which passenger embarked:
#     `C` - Cherbourg, `Q` - Queenstown, `S` - Southampton

# %% [markdown]
# We can read in the data stored in the file `titanic.csv` like this:

# %%
import pandas as pd

DATA_PATH = 'C:/Users/Bruker/OneDrive - Norwegian School of Economics/TECH2/TECH2-H25/data'

# URL to CSV file in GitHub repository
file = f'{DATA_PATH}/titanic.csv'

# Load sample data set of Titanic passengers. Individual fields are separated
# using a comma, which is the default.
df = pd.read_csv(file, sep=',')

# %% [markdown]
# We can now display the first and last three rows:

# %%
df.head(3)      # show first three rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S

# %%
df.tail(3)      # show last three rows
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 889          890         1       1                    Behr, Mr. Karl Howell
# 890          891         0       3                      Dooley, Mr. Patrick
#
#         Sex   Age      Ticket   Fare Cabin Embarked
# 888  female   NaN  W./C. 6607  23.45   NaN        S
# 889    male  26.0      111369  30.00  C148        C
# 890    male  32.0      370376   7.75   NaN        Q

# %% [markdown]
# To quickly compute some descriptive statistics for the
# *numerical* variables in the `DataFrame`, we use
# [`describe()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html):

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age        Fare
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118   32.204208
# std     257.353842    0.486592    0.836071   14.526497   49.693429
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    7.910400
# 50%     446.000000    0.000000    3.000000   28.000000   14.454200
# 75%     668.500000    1.000000    3.000000   38.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000  512.329200

# %% [markdown]
# Note that this automatically ignores the columns `Name`, `Sex`, `Ticket`
# and `Cabin` as they contain strings, and computing the mean, standard deviation, etc.
# of a string variable does not make sense.
#
# For categorical data, we can use
# [`value_counts()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html)
# to tabulate the number of unique values of a variable. For example, the following code tabulates passengers by sex:

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# Lastly, to see low-level information about the data type
# used in each column and the number of non-missing observations, we call
# [`info()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html):

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   Ticket       891 non-null    object
#  7   Fare         891 non-null    float64
#  8   Cabin        204 non-null    object
#  9   Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 69.7+ KB

# %% [markdown]
# Pandas automatically discards missing information
# in computations. For example, the age column has several missing values,
# so the number of reported `Non-Null` values is lower than for the other columns.

# %% [markdown]
# ***
# ## Indexing
#
# Pandas supports two types of indexing:
#
# 1.  Indexing by position. This is basically identical to the
#     indexing of other Python and NumPy containers.
# 2.  Indexing by label, i.e., by the values assigned to the row or column index.
#     These labels need not be integers in increasing order, as is the case
#     for NumPy.
#     We will see how to assign labels below.
#
# Pandas indexing is performed either by using brackets `[]`, or by using
# `.loc[]` for label indexing, or `.iloc[]` for positional indexing.
#
# Indexing via `[]` can be somewhat confusing:
#
# -   specifying `df['name']` returns the column `name` as a `Series` object.
# -   On the other hand, specifying a range such as `df[5:10]` returns the *rows*
#     associated with the *positions* 5,...,9.

# %% [markdown]
# *Example: Selecting columns*

# %%
import pandas as pd

# Set option to limit the number of rows displayed
pd.set_option('display.max_rows', 10)

# Load sample data of Titanic passengers
df = pd.read_csv(f'{DATA_PATH}/titanic.csv')
df['Name']               # select a single column
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                  Heikkinen, Miss Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                          Graham, Miss Margaret Edith
# 888              Johnston, Miss Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[['Name', 'Sex']]     # select multiple columns using a list
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                        Graham, Miss Margaret Edith  female
# 888            Johnston, Miss Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %% [markdown]
# Note: In order to select multiple columns you *must* specify these as a `list`, not a `tuple`.

# %% [markdown]
# *Example: Selecting rows by position*
#
# To return the rows at positions 1, 2 and 3 we use

# %%
df[1:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
#
#              Ticket     Fare Cabin Embarked
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S

# %% [markdown]
# Pandas follows the Python convention that indices are 0-based, and the
# endpoint of a slice is not included.

# %% [markdown]
# ### Creating and manipulating indices
#
# Pandas uses *labels* to index and align
# data. These can be integer values starting at 0 with increments of 1
# for each additional element, which is the default, but they need not be.
# The three main methods to create/manipulate indices are:
#
# 1.   Create a new `Series` or `DataFrame` object with a custom index
#     using the `index` argument.
# 2.   [`set_index(keys=['column1', ...])`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html)
#     uses the values of `column1`
#     and optionally additional columns as indices, discarding the current index.
# 3.   [`reset_index()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html)
#     resets the index to its default value, a sequence
#     of increasing integers starting at 0.

# %% [markdown]
# #### Creating custom indices
#
# First, consider the following code which creates a `Series` with
# three elements `[10, 20, 30]` using the default index `[0, 1, 2]`:

# %%
import pandas as pd

# Create Series with default integer index
pd.Series([10, 20, 30])
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# We can use the `index` argument to specify a custom index, for example
# one containing the lower-case characters `a`, `b`, `c` as follows:

# %%
# Create Series with custom index [a, b, c]
pd.Series([10, 20, 30], index=['a', 'b', 'c'])
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# #### Manipulating indices
#
# To modify the index of an *existing* `Series` or `DataFrame` object,
# we use the methods
# [`set_index()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html)
# and
# [`reset_index()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html).
# Note that these return a new object and leave the original `Series` or `DataFrame`
# unchanged. If we want to change the existing object, we need
# to pass the argument `inplace=True`.
#
# For example, we can replace the row index and use the Roman lower-case
#  characters `a`, `b`, `c`, ... as labels
# instead of integers:

# %%
# Create DataFrame with 2 columns
df = pd.DataFrame({'A': [10, 20, 30], 'B': ['a', 'b', 'c']})

df
# Out:
#     A  B
# 0  10  a
# 1  20  b
# 2  30  c

# %% [markdown]
# Since we did not specify any index, the default index $[0, 1, ...]$ is used.
# We can use [`set_index()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html)
# set the index to the values from a column, for example column `B`:

# %%
# Use column 'B' as index, store result in new DataFrame
df2 = df.set_index('B')

# Display updated DataFrame
df2
# Out:
#     A
# B
# a  10
# b  20
# c  30

# %% [markdown]
# Note that pandas operations are usually not in place, so only `df2` uses column `B` as the index, whereas the original `df` remains unchanged:

# %%
df
# Out:
#     A  B
# 0  10  a
# 1  20  b
# 2  30  c

# %% [markdown]
# We can use the `inplace=True` argument to `set_index()` to update the index in-place, even though the pandas project usually does not encourage users to change things in place:

# %%
# Set index in-place, i.e., df is modified
df.set_index('B', inplace=True)

df
# Out:
#     A
# B
# a  10
# b  20
# c  30

# %% [markdown]
# Importantly, when changing things in-place, pandas functions usually don't return anything (the return value is `None`), so it is a mistake to attempt to assign the return value to a variable.

# %% [markdown]
# We can now use these new labels to select records in the `DataFrame`:

# %%
# print first 2 rows using labels
df['a':'b']             # This is the same as df[:2]
# Out:
#     A
# B
# a  10
# b  20

# %% [markdown]
# Note that when specifying a range in terms of
# labels, the last element *is* included! Hence the row with index `c`
# in the above example is shown.
#
# We can reset the index to its default integer values using
# the `reset_index()` method:

# %%
# Reset index labels to default value (integers 0, 1, 2, ...) and print 
# first three rows
df.reset_index(drop=True).head(3)
# Out:
#     A
# 0  10
# 1  20
# 2  30

# %% [markdown]
# The `drop=True` argument tells pandas to throw away the old index
# values instead of storing them as a column of the resulting `DataFrame`.

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# Read in the following data files from the <TT>data/FRED</TT> folder and manipulate the dataframe index:
# <ol>
#     <li>Read in the file <TT>FRED_annual.csv</TT> and set the column <TT>Year</TT> as the index.</li>
#     <li>Read in the file <TT>FRED_monthly.csv</TT> and set the columns <TT>Year</TT> and <TT>Month</TT> as the index</li>
# </ol>
# Experiment what happens if you use the <TT>inplace=True</TT> and <TT>append=True</TT> options of <TT>set_index()</TT>.
#
# Restore the original (default) index after you are done.
# </div>

# %%
import pandas as pd

DATA_PATH = 'C:/Users/Bruker/OneDrive - Norwegian School of Economics/TECH2/TECH2-H25/data/FRED'

file = f'{DATA_PATH}/FRED_annual.csv'

df_annual = pd.read_csv(file)

# Set 'Year' as the index
df_annual.set_index('Year', inplace = True)

df_annual.head()

df_annual.reset_index().head()
# Out:
#    Year     GDP   CPI  UNRATE  FEDFUNDS  INFLATION
# 0  1954  2877.7  26.9     5.6       1.0        NaN
# 1  1955  3083.0  26.8     4.4       1.8       -0.4
# 2  1956  3148.8  27.2     4.1       2.7        1.5
# 3  1957  3215.1  28.1     4.3       3.1        3.3
# 4  1958  3191.2  28.9     6.8       1.6        2.8

# %%
import pandas as pd

DATA_PATH = 'C:/Users/Bruker/OneDrive - Norwegian School of Economics/TECH2/TECH2-H25/data/FRED'

file = f'{DATA_PATH}/FRED_monthly.csv'

df_monthly = pd.read_csv(file)

df_monthly.set_index(['Year', 'Month'], append = True)

df_monthly.head()

df_monthly.reset_index(drop = True).head()
# Out:
#          DATE  Year  Month   CPI  UNRATE  FEDFUNDS  REALRATE  LFPART
# 0  1948-01-01  1948      1  23.7     3.4       NaN       NaN    58.6
# 1  1948-02-01  1948      2  23.7     3.8       NaN       NaN    58.9
# 2  1948-03-01  1948      3  23.5     4.0       NaN       NaN    58.5
# 3  1948-04-01  1948      4  23.8     3.9       NaN       NaN    59.0
# 4  1948-05-01  1948      5  24.0     3.5       NaN       NaN    58.3

# %% [markdown]
# ### Selecting elements
#
# To more clearly distinguish between selection by label and by position,
# pandas provides the [`.loc[]`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html) and
# [`.iloc[]`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html) methods of indexing.
# To make your intention obvious, you should therefore adhere to the following
# rules:
#
# 1.  Use `df['name']` only to select *columns* and nothing else.
# 2.  Use `.loc[]` to select by label.
# 3.  Use `.iloc[]` to select by position.

# %% [markdown]
# **Selection by label**
#
# To illustrate, using `.loc[]` unambiguously indexes by label. First we create a demo data set with 3 columns and 5 rows:

# %%
import numpy as np
import pandas as pd
# Create demo data with 3 columns and 5 rows

# Column labels
columns = ['X', 'Y', 'Z']
# Row labels
rows = ['a', 'b', 'c', 'd', 'e']

values = np.arange(len(rows))

# Create data dictionary
data = {col: [f'{col}{val}' for val in values] for col in columns}

# Create DataFrame from dictionary
df = pd.DataFrame(data, index=rows)

# %% [markdown]
# We now use `.loc[]` to select rows and columns by label:

# %%
# Select rows 'b' to 'e', and columns 'X' and 'Y'
df.loc["b":"e", ["X", "Y"]]
# Out:
#     X   Y
# b  X1  Y1
# c  X2  Y2
# d  X3  Y3
# e  X4  Y4

# %% [markdown]
# With `.loc[]` we can even perform slicing on column names, which
# is not possible with the simpler `df[]` syntax:

# %%
df.loc['b':'e', 'X':'Z']
# Out:
#     X   Y   Z
# b  X1  Y1  Z1
# c  X2  Y2  Z2
# d  X3  Y3  Z3
# e  X4  Y4  Z4

# %% [markdown]
# This includes all the columns between `X` and `Z`,
# where the latter is included since we are slicing by label.
#
# Trying to pass in positional arguments will return an error for
# the given `DataFrame` since the index labels are `a`, `b`, `c`,...
# and not 0, 1, 2...

# %%
df.loc[0:4]
# Out:
# TypeError: cannot do slice indexing on Index with these indexers [0] of type int

# %% [markdown]
# However, we can reset the index to its default value. Then
# the index labels are integers and coincide with their position,
# so that `.loc[]` works:

# %%
df = df.reset_index(drop=True)      # reset index labels to integers,
                                    # drop original index
df.loc[0:4]
# Out:
#     X   Y   Z
# 0  X0  Y0  Z0
# 1  X1  Y1  Z1
# 2  X2  Y2  Z2
# 3  X3  Y3  Z3
# 4  X4  Y4  Z4

# %% [markdown]
# Again, the end point with label `4` is included because we
# are selecting by label.
#
# Indexing via `.loc[]` supports a few more types of arguments,
# see the [official documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#selection-by-label)
# for details.

# %% [markdown]
# **Selection by position**
#
# Conversely, if we want to select items exclusively by their position
# and ignore their labels, we use `.iloc[]`:

# %%
df.iloc[0:4, 0:2]           # select first 4 rows, first 2 columns
# Out:
#     X   Y
# 0  X0  Y0
# 1  X1  Y1
# 2  X2  Y2
# 3  X3  Y3

# %% [markdown]
# Again, `.iloc[]` supports a multitude of other arguments, see the [official documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#selection-by-position)
# for details.

# %% [markdown]
# **Boolean indexing**
#
# Similar to NumPy, pandas allows us to select a subset of rows in a `Series` or `DataFrame`
# if they satisfy some condition. The simplest use case is to create a
# column of boolean values (`True` or `False`) as a result of some logical operation:
#
#
#  This even works without
# explicitly using the `.loc[]` attribute:

# %%
import pandas as pd

# Read in Titanic passenger data
df = pd.read_csv(f'{DATA_PATH}/titanic.csv')

# Check whether passenger embarked in Southampton 
df['Embarked'] == "S"
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Embarked, Length: 891, dtype: bool

# %% [markdown]
# Such boolean arrays can be used to select a subset of entries:

# %%
df.loc[df['Embarked'] == 'S', 'Name':'Age']
# Out:
#                                              Name     Sex   Age
# 0                         Braund, Mr. Owen Harris    male  22.0
# 2                           Heikkinen, Miss Laina  female  26.0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                        Allen, Mr. William Henry    male  35.0
# 6                         McCarthy, Mr. Timothy J    male  54.0
# ..                                            ...     ...   ...
# 883                 Banfield, Mr. Frederick James    male  28.0
# 884                        Sutehall, Mr. Henry Jr    male  25.0
# 886                         Montvila, Rev. Juozas    male  27.0
# 887                   Graham, Miss Margaret Edith  female  19.0
# 888       Johnston, Miss Catherine Helen "Carrie"  female   NaN
#
# [644 rows x 3 columns]

# %% [markdown]
# Boolean indexing also works directly with `[]` without having to specify `.loc[]`, but then it is not possible to also select a subset of columns at the same time:

# %%
df[df['Embarked'] == 'S']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  \
# 0                         Braund, Mr. Owen Harris    male  22.0
# 2                           Heikkinen, Miss Laina  female  26.0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                        Allen, Mr. William Henry    male  35.0
# 6                         McCarthy, Mr. Timothy J    male  54.0
# ..                                            ...     ...   ...
# 883                 Banfield, Mr. Frederick James    male  28.0
# 884                        Sutehall, Mr. Henry Jr    male  25.0
# 886                         Montvila, Rev. Juozas    male  27.0
# 887                   Graham, Miss Margaret Edith  female  19.0
# 888       Johnston, Miss Catherine Helen "Carrie"  female   NaN
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 4              373450   8.0500   NaN        S
# 6               17463  51.8625   E46        S
# ..                ...      ...   ...      ...
# 883  C.A./SOTON 34068  10.5000   NaN        S
# 884   SOTON/OQ 392076   7.0500   NaN        S
# 886            211536  13.0000   NaN        S
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500   NaN        S
#
# [644 rows x 10 columns]

# %% [markdown]
# Multiple conditions can be combined using the `&` (logical and) or `|` (logical or) operators:

# %%
# Select men who embarked in Southampton
df.loc[(df['Embarked'] == 'S') & (df['Sex'] == 'male'), ['Name', 'Embarked', 'Sex']]
# Out:
#                                Name Embarked   Sex
# 0           Braund, Mr. Owen Harris        S  male
# 4          Allen, Mr. William Henry        S  male
# 6           McCarthy, Mr. Timothy J        S  male
# 7     Palsson, Master Gosta Leonard        S  male
# 12   Saundercock, Mr. William Henry        S  male
# ..                              ...      ...   ...
# 878              Laleff, Mr. Kristo        S  male
# 881              Markun, Mr. Johann        S  male
# 883   Banfield, Mr. Frederick James        S  male
# 884          Sutehall, Mr. Henry Jr        S  male
# 886           Montvila, Rev. Juozas        S  male
#
# [441 rows x 3 columns]

# %% [markdown]
# If we want to include rows where an observation takes on one of multiple values, the
# [`isin()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isin.html)
# method can be used:

# %%
# Select passengers who embarked in Southampton or Queenstown
df.loc[df['Embarked'].isin(('S', 'Q')), ['Name', 'Embarked']]
# Out:
#                                              Name Embarked
# 0                         Braund, Mr. Owen Harris        S
# 2                           Heikkinen, Miss Laina        S
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)        S
# 4                        Allen, Mr. William Henry        S
# 5                                Moran, Mr. James        Q
# ..                                            ...      ...
# 885          Rice, Mrs. William (Margaret Norton)        Q
# 886                         Montvila, Rev. Juozas        S
# 887                   Graham, Miss Margaret Edith        S
# 888       Johnston, Miss Catherine Helen "Carrie"        S
# 890                           Dooley, Mr. Patrick        Q
#
# [721 rows x 2 columns]

# %% [markdown]
# Finally, `DataFrame` implements a [`query()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html)
# method which allows us to combine multiple conditions in a single string in an intuitive fashion.
# Column names can be used directly within this string to put restrictions on their values.

# %%
# Select passengers who embarked in Southampton and were above age 70
df.query('Embarked == "S" & Age > 70')
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  Ticket    Fare Cabin Embarked
# 630  male  80.0   27042  30.000   A23        S
# 851  male  74.0  347060   7.775   NaN        S

# %% [markdown]
# <div class="alert alert-info">
# <h3> Your turn</h3>
# Load the Titanic passenger data set <TT>data/titanic.csv</TT> and select the following subsets of data:
# <ol>
#     <li>Select all passengers with passenger IDs from 10 to 20</li>
#     <li>Select the 10th to 20th (inclusive) row of the dataframe</li>
#     <li>Using <TT>query()</TT>, select the sub-sample of female passengers aged 30 to 40. Display only the columns <TT>Name</TT>, <TT>Age</TT>, and <TT>Sex</TT> (in that order)</li>
#     <li>Repeat the last exercise without using <TT>query()</TT></li>
#     <li>Select all men who embarked in Queenstown or Cherbourg</li>
# </ol>
# </div>

# %%
#Task 1
import pandas as pd

DATA_PATH = 'C:/Users/Bruker/OneDrive - Norwegian School of Economics/TECH2/TECH2-H25/data'
file = f'{DATA_PATH}/titanic.csv'

df = pd.read_csv(file)

df.loc[(df['PassengerId'] >= 10) & (df['PassengerId'] <= 20)]
# Out:
#     PassengerId  Survived  Pclass  \
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  \
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10                     Sandstrom, Miss Marguerite Rut  female   4.0
# 11                            Bonnell, Miss Elizabeth  female  58.0
# 12                     Saundercock, Mr. William Henry    male  20.0
# 13                        Andersson, Mr. Anders Johan    male  39.0
# 14                Vestrom, Miss Hulda Amanda Adolfina  female  14.0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 16                                Rice, Master Eugene    male   2.0
# 17                       Williams, Mr. Charles Eugene    male   NaN
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 19                            Masselmani, Mrs. Fatima  female   NaN
#
#        Ticket     Fare Cabin Embarked
# 9      237736  30.0708   NaN        C
# 10    PP 9549  16.7000    G6        S
# 11     113783  26.5500  C103        S
# 12  A/5. 2151   8.0500   NaN        S
# 13     347082  31.2750   NaN        S
# 14     350406   7.8542   NaN        S
# 15     248706  16.0000   NaN        S
# 16     382652  29.1250   NaN        Q
# 17     244373  13.0000   NaN        S
# 18     345763  18.0000   NaN        S
# 19       2649   7.2250   NaN        C

# %%
#Task 1 and 2
import pandas as pd

DATA_PATH = 'C:/Users/Bruker/OneDrive - Norwegian School of Economics/TECH2/TECH2-H25/data'
file = f'{DATA_PATH}/titanic.csv'

df = pd.read_csv(file)

df.loc[10:20]

#df.iloc[10:21]
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
#
#                                                  Name     Sex   Age  \
# 10                     Sandstrom, Miss Marguerite Rut  female   4.0
# 11                            Bonnell, Miss Elizabeth  female  58.0
# 12                     Saundercock, Mr. William Henry    male  20.0
# 13                        Andersson, Mr. Anders Johan    male  39.0
# 14                Vestrom, Miss Hulda Amanda Adolfina  female  14.0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 16                                Rice, Master Eugene    male   2.0
# 17                       Williams, Mr. Charles Eugene    male   NaN
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 19                            Masselmani, Mrs. Fatima  female   NaN
# 20                               Fynney, Mr. Joseph J    male  35.0
#
#        Ticket     Fare Cabin Embarked
# 10    PP 9549  16.7000    G6        S
# 11     113783  26.5500  C103        S
# 12  A/5. 2151   8.0500   NaN        S
# 13     347082  31.2750   NaN        S
# 14     350406   7.8542   NaN        S
# 15     248706  16.0000   NaN        S
# 16     382652  29.1250   NaN        Q
# 17     244373  13.0000   NaN        S
# 18     345763  18.0000   NaN        S
# 19       2649   7.2250   NaN        C
# 20     239865  26.0000   NaN        S

# %%
import pandas as pd

DATA_PATH = 'C:/Users/Bruker/OneDrive - Norwegian School of Economics/TECH2/TECH2-H25/data'

df = pd.read_csv(f'{DATA_PATH}/titanic.csv')

df.query('Sex == "female" & Age >= 30 & Age <= 40')[['Name', 'Age', 'Sex']]
# Out:
#                                                   Name   Age     Sex
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  31.0  female
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  38.0  female
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  40.0  female
# ..                                                 ...   ...     ...
# 801        Collyer, Mrs. Harvey (Charlotte Annie Tate)  31.0  female
# 809     Chambers, Mrs. Norman Campbell (Bertha Griggs)  33.0  female
# 835                         Compton, Miss Sara Rebecca  39.0  female
# 842                             Serepeca, Miss Augusta  30.0  female
# 885               Rice, Mrs. William (Margaret Norton)  39.0  female
#
# [66 rows x 3 columns]

# %%
#Task 4
import pandas as pd

DATA_PATH = 'C:/Users/Bruker/OneDrive - Norwegian School of Economics/TECH2/TECH2-H25/data'

df = pd.read_csv(f'{DATA_PATH}/titanic.csv')

df.loc[(df['Sex'] == 'female') & (df['Age'] >= 30) & (df['Age'] <= 40), ['Name', 'Age', 'Sex']]
# Out:
#                                                   Name   Age     Sex
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  31.0  female
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  38.0  female
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  40.0  female
# ..                                                 ...   ...     ...
# 801        Collyer, Mrs. Harvey (Charlotte Annie Tate)  31.0  female
# 809     Chambers, Mrs. Norman Campbell (Bertha Griggs)  33.0  female
# 835                         Compton, Miss Sara Rebecca  39.0  female
# 842                             Serepeca, Miss Augusta  30.0  female
# 885               Rice, Mrs. William (Margaret Norton)  39.0  female
#
# [66 rows x 3 columns]

# %%
#Task 5

import pandas as pd

DATA_PATH = 'C:/Users/Bruker/OneDrive - Norwegian School of Economics/TECH2/TECH2-H25/data'
file = f'{DATA_PATH}/titanic.csv'

df = pd.read_csv(file)

df.loc[(df['Sex'] == 'male') & (df['Embarked'].isin(('Q', 'C')))]
# Out:
#      PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 0              1         0       3        Braund, Mr. Owen Harris  male  22.0
# 4              5         0       3       Allen, Mr. William Henry  male  35.0
# 5              6         0       3               Moran, Mr. James  male   NaN
# 6              7         0       1        McCarthy, Mr. Timothy J  male  54.0
# 7              8         0       3  Palsson, Master Gosta Leonard  male   2.0
# ..           ...       ...     ...                            ...   ...   ...
# 881          882         0       3             Markun, Mr. Johann  male  33.0
# 883          884         0       2  Banfield, Mr. Frederick James  male  28.0
# 884          885         0       3         Sutehall, Mr. Henry Jr  male  25.0
# 886          887         0       2          Montvila, Rev. Juozas  male  27.0
# 890          891         0       3            Dooley, Mr. Patrick  male  32.0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 4              373450   8.0500   NaN        S
# 5              330877   8.4583   NaN        Q
# 6               17463  51.8625   E46        S
# 7              349909  21.0750   NaN        S
# ..                ...      ...   ...      ...
# 881            349257   7.8958   NaN        S
# 883  C.A./SOTON 34068  10.5000   NaN        S
# 884   SOTON/OQ 392076   7.0500   NaN        S
# 886            211536  13.0000   NaN        S
# 890            370376   7.7500   NaN        Q
#
# [482 rows x 10 columns]

# %% [markdown]
# ***
# ## Working with time series data
#
# In economics and finance, we frequently work with time series data, i.e., observations that are associated with a particular point in time (time stamp) or a time period. pandas offers comprehensive support for such data, in particular if the time stamp or time period is used as the index of a `Series` or `DataFrame`.
# This section presents a few of the most important concepts, see the official [documentation](https://pandas.pydata.org/docs/user_guide/timeseries.html) for a comprehensive guide.
#
# To illustrate, let's construct a set of daily data for the first three months of 2024, i.e., the period 2024-01-01 to 2024-03-31 using the
# [`date_range()`](https://pandas.pydata.org/docs/reference/api/pandas.date_range.html) function
# (we use the data format `YYYY-MM-DD` in this section, but pandas also supports other date formats).

# %%
import pandas as pd
import numpy as np

# Create sequence of dates from 2024-01-01 to 2024-03-31
# at daily frequency
index = pd.date_range(start="2024-01-01", end="2024-03-31", freq="D")

# Use date range as index for Series with some artificial data
data = pd.Series(np.arange(len(index)), index=index)

# Print first 5 observations
data.head(5)
# Out:
# 2024-01-01    0
# 2024-01-02    1
# 2024-01-03    2
# 2024-01-04    3
# 2024-01-05    4
# Freq: D, dtype: int64

# %% [markdown]
# ### Indexing with date/time indices
#
# pandas implements several convenient ways to select observations associated with a particular date or a set of dates. For example, if we want to select one specific date, we can pass it as a string to `.loc[]`:

# %%
# Select single observation by date
data.loc["2024-01-01"]
# Out:
# np.int64(0)

# %% [markdown]
# It is also possible to select a time period by passing a start and end point (where the end point is included, as usual with label-based indexing in pandas):

# %%
# Select first 5 days
data.loc["2024-01-01":"2024-01-05"]
# Out:
# 2024-01-01    0
# 2024-01-02    1
# 2024-01-03    2
# 2024-01-04    3
# 2024-01-05    4
# Freq: D, dtype: int64

# %% [markdown]
# A particularly useful way to index time periods is a to pass a partial index. For example, if we want to select all observations from January 2024, we could use the range `'2024-01-01':'2024-01-31'`, but it is much easier to specify the partial index `'2024-01'` instead which includes all observations from January.

# %%
# Select all observations from January 2024
data.loc["2024-01"]
# Out:
# 2024-01-01     0
# 2024-01-02     1
# 2024-01-03     2
# 2024-01-04     3
# 2024-01-05     4
#               ..
# 2024-01-27    26
# 2024-01-28    27
# 2024-01-29    28
# 2024-01-30    29
# 2024-01-31    30
# Freq: D, Length: 31, dtype: int64

# %% [markdown]
# ### Lags, differences, and other useful transformations
#
# When working with time series data, we often need to create lags or leads of a variable (e.g., if we want to include lagged values in a regression model). In pandas, this is done using
# [`shift()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shift.html)
# which shifts the index by the desired number of periods (default: 1). For example, invoking
# `shift(1)` creates lagged observations of each column in the `DataFrame`:

# %%
# Lag observations by 1 period
data.shift(1).head(5)
# Out:
# 2024-01-01    NaN
# 2024-01-02    0.0
# 2024-01-03    1.0
# 2024-01-04    2.0
# 2024-01-05    3.0
# Freq: D, dtype: float64

# %% [markdown]
# We can use the
# [`diff()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.diff.html)
# method to compute differences over a given number of periods:

# %%
# Compute difference between consecutive observations
data.diff(1).head(5)
# Out:
# 2024-01-01    NaN
# 2024-01-02    1.0
# 2024-01-03    1.0
# 2024-01-04    1.0
# 2024-01-05    1.0
# Freq: D, dtype: float64

# %% [markdown]
# Note that `diff()` is identical to manually computing the difference with the lagged value like this:
#
# ```python
# data - data.shift()
# ```

# %% [markdown]
# Additionally, we can use
# [`pct_change()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pct_change.html)
# which computes the percentage change (the relative difference) over a given number of periods (default: 1).

# %%
# Compute percentage change vs. previous period
data.pct_change().head(5)
# Out:
# 2024-01-01         NaN
# 2024-01-02         inf
# 2024-01-03    1.000000
# 2024-01-04    0.500000
# 2024-01-05    0.333333
# Freq: D, dtype: float64

# %% [markdown]
# Again, this is just a convenience method that is a short-cut for manually computing the percentage change:
#
# ```python
# (data - data.shift()) / data.shift()
# ```
